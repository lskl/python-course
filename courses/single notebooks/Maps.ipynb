# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from geopy.geocoders import Nominatim

# %%
m = Basemap( width=12000000, height=9000000, projection='lcc', resolution='c', 
             lat_1=45, lat_2=55, lat_0=50, lon_0=-107 )
m.drawcoastlines()
m.drawlsmask( land_color='coral', ocean_color='aqua', lakes=True )
plt.show()

# %%
m.readshapefile( 'st99_d00', name='states', drawbounds=True )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-bae311e7b8c7> in <module>
# ----> 1 m.readshapefile( 'st99_d00', name='states', drawbounds=True )
#       2 plt.show()
#
# /usr/local/lib/python3.6/dist-packages/mpl_toolkits/basemap/__init__.py in readshapefile(self, shapefile, name, drawbounds, zorder, linewidth, color, antialiased, ax, default_encoding)
#    2128         shp.default_encoding = default_encoding
#    2129         if not os.path.exists('%s.shp'%shapefile):
# -> 2130             raise IOError('cannot locate %s.shp'%shapefile)
#    2131         if not os.path.exists('%s.shx'%shapefile):
#    2132             raise IOError('cannot locate %s.shx'%shapefile)
#
# OSError: cannot locate st99_d00.shp
